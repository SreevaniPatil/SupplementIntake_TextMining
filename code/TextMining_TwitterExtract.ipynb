# %%
#importing the required libraries
import os
import time
from ast import literal_eval
from datetime import datetime
import pandas as pd
import snscrape.modules.twitter as sntwitter # the magic
import warnings
warnings.filterwarnings('ignore')

# %%
#setting up the directory
#root_dir = os.path.abspath(os.path.join(os.path.dirname("."), '.'))
#output: /Users/sbp

# %%
#Extractor Module
class ExtractTweets:
    
    def __init__(self, 
                 minTweetCountPerDay=10, 
                 minRetweetCount=0,
                 minLikeCount=0, 
                 minFollowersCount=0, 
                 VerifiedStatus=None, 
                 saveBufferDuration=3600):
        """
        Accepts basic input params each of integer datatype, except for VerifiedStatus which accepts boolean or None.
        """
        self.start_timer = datetime.strptime(time.strftime("%Y-%m-%d %H:%M:%S"), "%Y-%m-%d %H:%M:%S")
        self.min_tweet_count_perDay = minTweetCountPerDay
        self.minRetweetCount = minRetweetCount
        self.minLikeCount = minLikeCount
        self.minFollowersCount = minFollowersCount
        self.VerifiedStatus = VerifiedStatus                           
        self.tweets_df = pd.DataFrame(columns=['date', 'tweet', 'lang', 'retweetCount', 'likeCount', 'replyCount', 
                                               'username', 'user_followersCount','user_friendsCount', 'verifiedStatus', 
                                               'tweet_url', 'hastags', 'chr_count', 'topic'])
        self.save_buffer_duration = saveBufferDuration
        return

    def save_copy(self):
        """
        Saves a temp copy for restoration and prevent API time limit exceed error.
        
        :return:
        pandas dataframe containing twitter record-data.
        """
        data = self.tweets_df.reset_index(drop=True)
        data['date'] = data['date'].apply(lambda x: pd.to_datetime(x).strftime('%Y-%m-%d'))
        for filename in os.listdir("."):
            if filename.endswith('local.csv'):
                os.remove(filename)
        data.to_csv("./save_{}_local.csv".format(data.date.max()), index=False)
        return data
        
    def getTweets(self, start_date, end_date, keywords):
        """
        Extracts historical twitter data.
        
        :params:
        start_date - str in "YYYY-MM-DD" format
        end_date - str in "YYYY-MM-DD" format
        keywords - list of tuples, 
            e.g, [('recession'), ('football, 'worldcup', 'fifa'), ('war', 'ukraine')]
            e.g. ['recession']
        
        :return:
        pandas dataframe with features as:
         date: Tweet Timestamp
         tweet: tweet content
         lang: language classifer used by parent api
         retweetCount: tweet retweeted count
         likeCount: tweet like count
         replyCount: number of replies to original tweet
         username: user who tweeted
         user_followersCount: number of followers user has (tells you how popular the avg tweets are)
         user_friendsCount: number of friends user has
         verifiedStatus: If the user is Verified or not (i.e. pays 8 bucks every month!)
         tweet_url: Link of original tweet (click and see)
         hastags: If any hastags were used (hastags are important for search and info retrieval)
         chr_count: number of english characters in the original tweet
         topic: keywords you used for searching tweets (kind of labels)
        """
        
        if not(isinstance(keywords, list) or isinstance(keywords, tuple)):
            raise Exception("Incorrect Input Format! Please pass a list")
        
        for topic in keywords:
            # for saving local copies every buffer_hour
            st_time = datetime.strptime(time.strftime("%Y-%m-%d %H:%M:%S"), "%Y-%m-%d %H:%M:%S")
            date = pd.to_datetime(start_date, format='%Y-%m-%d')
            e_date = pd.to_datetime(end_date, format='%Y-%m-%d') + pd.to_timedelta(1, unit='d')
            if isinstance(topic, tuple) or isinstance(topic, list):
                topic = " ".join(topic)
            search_query = topic
            print("search_query:", search_query)
        
            while date != e_date:
                nxt_date = date + pd.to_timedelta(1, unit='d')
                content = '{} since:{} until:{}'.format(search_query, date.strftime('%Y-%m-%d'), nxt_date.strftime('%Y-%m-%d'))
                print(content)
                
                # check for save buffer duration (set to 1 Hr by default)
                delta_buffer = (datetime.strptime(time.strftime("%Y-%m-%d %H:%M:%S"), "%Y-%m-%d %H:%M:%S") - st_time).seconds
                if delta_buffer >= self.save_buffer_duration:
                    self.save_copy()
                    # reset buffer
                    st_time = datetime.strptime(time.strftime("%Y-%m-%d %H:%M:%S"), "%Y-%m-%d %H:%M:%S")

                lst_tweets = []
                for counter, tweet in enumerate(sntwitter.TwitterSearchScraper(content).get_items()):
                    if counter+1 > self.min_tweet_count_perDay: 
                        break
                    if tweet.likeCount >= self.minLikeCount \
                        or tweet.retweetCount >= self.minRetweetCount \
                        or tweet.user.followersCount >= self.minFollowersCount \
                        or (tweet.user.verified and isinstance(tweet.user.verified, bool) and tweet.user.verified == self.VerifiedStatus):
                        
                        # ----------------------------------------------------------------
                        # Potential custom preprocessing module here: 
                        # 1. Simple and short: https://www.kaggle.com/code/zenbird01/pranjalpathak-semantic-clustering-v1-0/notebook
                        # 2. Advanced: ./NLP_basics_preprocessing_vectorization_similarity.ipynb
                        # 3. Best: Check github - https://github.com/pranzell/NLP_Tools
                        # ----------------------------------------------------------------
                        
                        lst_tweets.append([
                            tweet.date, 
                            tweet.content, 
                            tweet.lang,
                            tweet.retweetCount,
                            tweet.likeCount,
                            tweet.replyCount,
                            tweet.user.username, 
                            tweet.user.followersCount, 
                            tweet.user.friendsCount, 
                            tweet.user.verified,
                            tweet.url,
                            tweet.hashtags,
                            len(str(tweet.content).strip()),
                            topic])
                
                self.tweets_df = self.tweets_df.append(pd.DataFrame(lst_tweets, columns=self.tweets_df.columns))
                date = nxt_date
        
        print("\n\nTOTAL TIME TAKEN {} minutes".format(((datetime.strptime(time.strftime("%Y-%m-%d %H:%M:%S"), "%Y-%m-%d %H:%M:%S") - self.start_timer).seconds)/60.0))
        return self.save_copy()
    
    
    def preprocess_shortText(self, text_col):
        # refer to Preprocessing ipynb file
        # https://github.com/pranzell/NLP_Tools
        pass

# %%
#Configuration
minTweetCountPerDay=50
minRetweetCount=100
minLikeCount=100
minFollowersCount=200
VerifiedStatus=None
saveBufferDuration=3600 # in seconds

start_date = "2022-06-01"
end_date = "2023-01-31"

# list of tuples, or a list of single str items check function definition `getTweets()`
#keywords = [('veganism'), ('vegan','govegan','veganfortheanimals','animalsrights','veganism')]
#keywords = [('non veganism'), ('antivegan','exvegan','yestomeat','meatlover','antiveganism')]

# %%
#Execution
#keywords = [('non veganism'), ('antivegan','exvegan','yestomeat','meatlover','antiveganism')]

et = ExtractTweets(minTweetCountPerDay, minRetweetCount, minLikeCount, minFollowersCount, VerifiedStatus, saveBufferDuration)
twitter_data = et.getTweets(start_date, end_date, keywords)
# Out:
# search_query: non veganism
# non veganism since:2022-06-01 until:2022-06-02
# non veganism since:2022-06-02 until:2022-06-03
# non veganism since:2022-06-03 until:2022-06-04
# non veganism since:2022-06-04 until:2022-06-05
# non veganism since:2022-06-05 until:2022-06-06
# non veganism since:2022-06-06 until:2022-06-07
# non veganism since:2022-06-07 until:2022-06-08
# non veganism since:2022-06-08 until:2022-06-09
# non veganism since:2022-06-09 until:2022-06-10
# non veganism since:2022-06-10 until:2022-06-11
# non veganism since:2022-06-11 until:2022-06-12
# non veganism since:2022-06-12 until:2022-06-13
# non veganism since:2022-06-13 until:2022-06-14
# non veganism since:2022-06-14 until:2022-06-15
# non veganism since:2022-06-15 until:2022-06-16
# non veganism since:2022-06-16 until:2022-06-17
# non veganism since:2022-06-17 until:2022-06-18
# non veganism since:2022-06-18 until:2022-06-19
# non veganism since:2022-06-19 until:2022-06-20
# non veganism since:2022-06-20 until:2022-06-21
# non veganism since:2022-06-21 until:2022-06-22
# non veganism since:2022-06-22 until:2022-06-23
# non veganism since:2022-06-23 until:2022-06-24
# non veganism since:2022-06-24 until:2022-06-25
# non veganism since:2022-06-25 until:2022-06-26
# non veganism since:2022-06-26 until:2022-06-27
# non veganism since:2022-06-27 until:2022-06-28
# non veganism since:2022-06-28 until:2022-06-29
# non veganism since:2022-06-29 until:2022-06-30
# non veganism since:2022-06-30 until:2022-07-01
# non veganism since:2022-07-01 until:2022-07-02
# non veganism since:2022-07-02 until:2022-07-03
# non veganism since:2022-07-03 until:2022-07-04
# non veganism since:2022-07-04 until:2022-07-05
# non veganism since:2022-07-05 until:2022-07-06
# non veganism since:2022-07-06 until:2022-07-07
# non veganism since:2022-07-07 until:2022-07-08
# non veganism since:2022-07-08 until:2022-07-09
# non veganism since:2022-07-09 until:2022-07-10
# non veganism since:2022-07-10 until:2022-07-11
# non veganism since:2022-07-11 until:2022-07-12
# non veganism since:2022-07-12 until:2022-07-13
# non veganism since:2022-07-13 until:2022-07-14
# non veganism since:2022-07-14 until:2022-07-15
# non veganism since:2022-07-15 until:2022-07-16
# non veganism since:2022-07-16 until:2022-07-17
# non veganism since:2022-07-17 until:2022-07-18
# non veganism since:2022-07-18 until:2022-07-19
# non veganism since:2022-07-19 until:2022-07-20
# non veganism since:2022-07-20 until:2022-07-21
# non veganism since:2022-07-21 until:2022-07-22
# non veganism since:2022-07-22 until:2022-07-23
# non veganism since:2022-07-23 until:2022-07-24
# non veganism since:2022-07-24 until:2022-07-25
# non veganism since:2022-07-25 until:2022-07-26
# non veganism since:2022-07-26 until:2022-07-27
# non veganism since:2022-07-27 until:2022-07-28
# non veganism since:2022-07-28 until:2022-07-29
# non veganism since:2022-07-29 until:2022-07-30
# non veganism since:2022-07-30 until:2022-07-31
# non veganism since:2022-07-31 until:2022-08-01
# non veganism since:2022-08-01 until:2022-08-02
# non veganism since:2022-08-02 until:2022-08-03
# non veganism since:2022-08-03 until:2022-08-04
# non veganism since:2022-08-04 until:2022-08-05
# non veganism since:2022-08-05 until:2022-08-06
# non veganism since:2022-08-06 until:2022-08-07
# non veganism since:2022-08-07 until:2022-08-08
# non veganism since:2022-08-08 until:2022-08-09
# non veganism since:2022-08-09 until:2022-08-10
# non veganism since:2022-08-10 until:2022-08-11
# non veganism since:2022-08-11 until:2022-08-12
# non veganism since:2022-08-12 until:2022-08-13
# non veganism since:2022-08-13 until:2022-08-14
# non veganism since:2022-08-14 until:2022-08-15
# non veganism since:2022-08-15 until:2022-08-16
# non veganism since:2022-08-16 until:2022-08-17
# non veganism since:2022-08-17 until:2022-08-18
# non veganism since:2022-08-18 until:2022-08-19
# non veganism since:2022-08-19 until:2022-08-20
# non veganism since:2022-08-20 until:2022-08-21
# non veganism since:2022-08-21 until:2022-08-22
# non veganism since:2022-08-22 until:2022-08-23
# non veganism since:2022-08-23 until:2022-08-24
# non veganism since:2022-08-24 until:2022-08-25
# non veganism since:2022-08-25 until:2022-08-26
# non veganism since:2022-08-26 until:2022-08-27
# non veganism since:2022-08-27 until:2022-08-28
# non veganism since:2022-08-28 until:2022-08-29
# non veganism since:2022-08-29 until:2022-08-30
# non veganism since:2022-08-30 until:2022-08-31
# non veganism since:2022-08-31 until:2022-09-01
# non veganism since:2022-09-01 until:2022-09-02
# non veganism since:2022-09-02 until:2022-09-03
# non veganism since:2022-09-03 until:2022-09-04
# non veganism since:2022-09-04 until:2022-09-05
# non veganism since:2022-09-05 until:2022-09-06
# non veganism since:2022-09-06 until:2022-09-07
# non veganism since:2022-09-07 until:2022-09-08
# non veganism since:2022-09-08 until:2022-09-09
# non veganism since:2022-09-09 until:2022-09-10
# non veganism since:2022-09-10 until:2022-09-11
# non veganism since:2022-09-11 until:2022-09-12
# non veganism since:2022-09-12 until:2022-09-13
# non veganism since:2022-09-13 until:2022-09-14
# non veganism since:2022-09-14 until:2022-09-15
# non veganism since:2022-09-15 until:2022-09-16
# non veganism since:2022-09-16 until:2022-09-17
# non veganism since:2022-09-17 until:2022-09-18
# non veganism since:2022-09-18 until:2022-09-19
# non veganism since:2022-09-19 until:2022-09-20
# non veganism since:2022-09-20 until:2022-09-21
# non veganism since:2022-09-21 until:2022-09-22
# non veganism since:2022-09-22 until:2022-09-23
# non veganism since:2022-09-23 until:2022-09-24
# non veganism since:2022-09-24 until:2022-09-25
# non veganism since:2022-09-25 until:2022-09-26
# non veganism since:2022-09-26 until:2022-09-27
# non veganism since:2022-09-27 until:2022-09-28
# non veganism since:2022-09-28 until:2022-09-29
# non veganism since:2022-09-29 until:2022-09-30
# non veganism since:2022-09-30 until:2022-10-01
# non veganism since:2022-10-01 until:2022-10-02
# non veganism since:2022-10-02 until:2022-10-03
# non veganism since:2022-10-03 until:2022-10-04
# non veganism since:2022-10-04 until:2022-10-05
# non veganism since:2022-10-05 until:2022-10-06
# non veganism since:2022-10-06 until:2022-10-07
# non veganism since:2022-10-07 until:2022-10-08
# non veganism since:2022-10-08 until:2022-10-09
# non veganism since:2022-10-09 until:2022-10-10
# non veganism since:2022-10-10 until:2022-10-11
# non veganism since:2022-10-11 until:2022-10-12
# non veganism since:2022-10-12 until:2022-10-13
# non veganism since:2022-10-13 until:2022-10-14
# non veganism since:2022-10-14 until:2022-10-15
# non veganism since:2022-10-15 until:2022-10-16
# non veganism since:2022-10-16 until:2022-10-17
# non veganism since:2022-10-17 until:2022-10-18
# non veganism since:2022-10-18 until:2022-10-19
# non veganism since:2022-10-19 until:2022-10-20
# non veganism since:2022-10-20 until:2022-10-21
# non veganism since:2022-10-21 until:2022-10-22
# non veganism since:2022-10-22 until:2022-10-23
# non veganism since:2022-10-23 until:2022-10-24
# non veganism since:2022-10-24 until:2022-10-25
# non veganism since:2022-10-25 until:2022-10-26
# non veganism since:2022-10-26 until:2022-10-27
# non veganism since:2022-10-27 until:2022-10-28
# non veganism since:2022-10-28 until:2022-10-29
# non veganism since:2022-10-29 until:2022-10-30
# non veganism since:2022-10-30 until:2022-10-31
# non veganism since:2022-10-31 until:2022-11-01
# non veganism since:2022-11-01 until:2022-11-02
# non veganism since:2022-11-02 until:2022-11-03
# non veganism since:2022-11-03 until:2022-11-04
# non veganism since:2022-11-04 until:2022-11-05
# non veganism since:2022-11-05 until:2022-11-06
# non veganism since:2022-11-06 until:2022-11-07
# non veganism since:2022-11-07 until:2022-11-08
# non veganism since:2022-11-08 until:2022-11-09
# non veganism since:2022-11-09 until:2022-11-10
# non veganism since:2022-11-10 until:2022-11-11
# non veganism since:2022-11-11 until:2022-11-12
# non veganism since:2022-11-12 until:2022-11-13
# non veganism since:2022-11-13 until:2022-11-14
# non veganism since:2022-11-14 until:2022-11-15
# non veganism since:2022-11-15 until:2022-11-16
# non veganism since:2022-11-16 until:2022-11-17
# non veganism since:2022-11-17 until:2022-11-18
# non veganism since:2022-11-18 until:2022-11-19
# non veganism since:2022-11-19 until:2022-11-20
# non veganism since:2022-11-20 until:2022-11-21
# non veganism since:2022-11-21 until:2022-11-22
# non veganism since:2022-11-22 until:2022-11-23
# non veganism since:2022-11-23 until:2022-11-24
# non veganism since:2022-11-24 until:2022-11-25
# non veganism since:2022-11-25 until:2022-11-26
# non veganism since:2022-11-26 until:2022-11-27
# non veganism since:2022-11-27 until:2022-11-28
# non veganism since:2022-11-28 until:2022-11-29
# non veganism since:2022-11-29 until:2022-11-30
# non veganism since:2022-11-30 until:2022-12-01
# non veganism since:2022-12-01 until:2022-12-02
# non veganism since:2022-12-02 until:2022-12-03
# non veganism since:2022-12-03 until:2022-12-04
# non veganism since:2022-12-04 until:2022-12-05
# non veganism since:2022-12-05 until:2022-12-06
# non veganism since:2022-12-06 until:2022-12-07
# non veganism since:2022-12-07 until:2022-12-08
# non veganism since:2022-12-08 until:2022-12-09
# non veganism since:2022-12-09 until:2022-12-10
# non veganism since:2022-12-10 until:2022-12-11
# non veganism since:2022-12-11 until:2022-12-12
# non veganism since:2022-12-12 until:2022-12-13
# non veganism since:2022-12-13 until:2022-12-14
# non veganism since:2022-12-14 until:2022-12-15
# non veganism since:2022-12-15 until:2022-12-16
# non veganism since:2022-12-16 until:2022-12-17
# non veganism since:2022-12-17 until:2022-12-18
# non veganism since:2022-12-18 until:2022-12-19
# non veganism since:2022-12-19 until:2022-12-20
# non veganism since:2022-12-20 until:2022-12-21
# non veganism since:2022-12-21 until:2022-12-22
# non veganism since:2022-12-22 until:2022-12-23
# non veganism since:2022-12-23 until:2022-12-24
# non veganism since:2022-12-24 until:2022-12-25
# non veganism since:2022-12-25 until:2022-12-26
# non veganism since:2022-12-26 until:2022-12-27
# non veganism since:2022-12-27 until:2022-12-28
# non veganism since:2022-12-28 until:2022-12-29
# non veganism since:2022-12-29 until:2022-12-30
# non veganism since:2022-12-30 until:2022-12-31
# non veganism since:2022-12-31 until:2023-01-01
# non veganism since:2023-01-01 until:2023-01-02
# non veganism since:2023-01-02 until:2023-01-03
# non veganism since:2023-01-03 until:2023-01-04
# non veganism since:2023-01-04 until:2023-01-05
# non veganism since:2023-01-05 until:2023-01-06
# non veganism since:2023-01-06 until:2023-01-07
# non veganism since:2023-01-07 until:2023-01-08
# non veganism since:2023-01-08 until:2023-01-09
# non veganism since:2023-01-09 until:2023-01-10
# non veganism since:2023-01-10 until:2023-01-11
# non veganism since:2023-01-11 until:2023-01-12
# non veganism since:2023-01-12 until:2023-01-13
# non veganism since:2023-01-13 until:2023-01-14
# non veganism since:2023-01-14 until:2023-01-15
# non veganism since:2023-01-15 until:2023-01-16
# non veganism since:2023-01-16 until:2023-01-17
# non veganism since:2023-01-17 until:2023-01-18
# non veganism since:2023-01-18 until:2023-01-19
# non veganism since:2023-01-19 until:2023-01-20
# non veganism since:2023-01-20 until:2023-01-21
# non veganism since:2023-01-21 until:2023-01-22
# non veganism since:2023-01-22 until:2023-01-23
# non veganism since:2023-01-23 until:2023-01-24
# non veganism since:2023-01-24 until:2023-01-25
# non veganism since:2023-01-25 until:2023-01-26
# non veganism since:2023-01-26 until:2023-01-27
# non veganism since:2023-01-27 until:2023-01-28
# non veganism since:2023-01-28 until:2023-01-29
# non veganism since:2023-01-29 until:2023-01-30
# non veganism since:2023-01-30 until:2023-01-31
# non veganism since:2023-01-31 until:2023-02-01
# search_query: antivegan exvegan yestomeat meatlover antiveganism
# antivegan exvegan yestomeat meatlover antiveganism since:2022-06-01 until:2022-06-02
# antivegan exvegan yestomeat meatlover antiveganism since:2022-06-02 until:2022-06-03
# antivegan exvegan yestomeat meatlover antiveganism since:2022-06-03 until:2022-06-04
# antivegan exvegan yestomeat meatlover antiveganism since:2022-06-04 until:2022-06-05
# antivegan exvegan yestomeat meatlover antiveganism since:2022-06-05 until:2022-06-06
# antivegan exvegan yestomeat meatlover antiveganism since:2022-06-06 until:2022-06-07
# antivegan exvegan yestomeat meatlover antiveganism since:2022-06-07 until:2022-06-08
# antivegan exvegan yestomeat meatlover antiveganism since:2022-06-08 until:2022-06-09
# antivegan exvegan yestomeat meatlover antiveganism since:2022-06-09 until:2022-06-10
# antivegan exvegan yestomeat meatlover antiveganism since:2022-06-10 until:2022-06-11
# antivegan exvegan yestomeat meatlover antiveganism since:2022-06-11 until:2022-06-12
# antivegan exvegan yestomeat meatlover antiveganism since:2022-06-12 until:2022-06-13
# antivegan exvegan yestomeat meatlover antiveganism since:2022-06-13 until:2022-06-14
# antivegan exvegan yestomeat meatlover antiveganism since:2022-06-14 until:2022-06-15
# antivegan exvegan yestomeat meatlover antiveganism since:2022-06-15 until:2022-06-16
# antivegan exvegan yestomeat meatlover antiveganism since:2022-06-16 until:2022-06-17
# antivegan exvegan yestomeat meatlover antiveganism since:2022-06-17 until:2022-06-18
# antivegan exvegan yestomeat meatlover antiveganism since:2022-06-18 until:2022-06-19
# antivegan exvegan yestomeat meatlover antiveganism since:2022-06-19 until:2022-06-20
# antivegan exvegan yestomeat meatlover antiveganism since:2022-06-20 until:2022-06-21
# antivegan exvegan yestomeat meatlover antiveganism since:2022-06-21 until:2022-06-22
# antivegan exvegan yestomeat meatlover antiveganism since:2022-06-22 until:2022-06-23
# antivegan exvegan yestomeat meatlover antiveganism since:2022-06-23 until:2022-06-24
# antivegan exvegan yestomeat meatlover antiveganism since:2022-06-24 until:2022-06-25
# antivegan exvegan yestomeat meatlover antiveganism since:2022-06-25 until:2022-06-26
# antivegan exvegan yestomeat meatlover antiveganism since:2022-06-26 until:2022-06-27
# antivegan exvegan yestomeat meatlover antiveganism since:2022-06-27 until:2022-06-28
# antivegan exvegan yestomeat meatlover antiveganism since:2022-06-28 until:2022-06-29
# antivegan exvegan yestomeat meatlover antiveganism since:2022-06-29 until:2022-06-30
# antivegan exvegan yestomeat meatlover antiveganism since:2022-06-30 until:2022-07-01
# antivegan exvegan yestomeat meatlover antiveganism since:2022-07-01 until:2022-07-02
# antivegan exvegan yestomeat meatlover antiveganism since:2022-07-02 until:2022-07-03
# antivegan exvegan yestomeat meatlover antiveganism since:2022-07-03 until:2022-07-04
# antivegan exvegan yestomeat meatlover antiveganism since:2022-07-04 until:2022-07-05
# antivegan exvegan yestomeat meatlover antiveganism since:2022-07-05 until:2022-07-06
# antivegan exvegan yestomeat meatlover antiveganism since:2022-07-06 until:2022-07-07
# antivegan exvegan yestomeat meatlover antiveganism since:2022-07-07 until:2022-07-08
# antivegan exvegan yestomeat meatlover antiveganism since:2022-07-08 until:2022-07-09
# antivegan exvegan yestomeat meatlover antiveganism since:2022-07-09 until:2022-07-10
# antivegan exvegan yestomeat meatlover antiveganism since:2022-07-10 until:2022-07-11
# antivegan exvegan yestomeat meatlover antiveganism since:2022-07-11 until:2022-07-12
# antivegan exvegan yestomeat meatlover antiveganism since:2022-07-12 until:2022-07-13
# antivegan exvegan yestomeat meatlover antiveganism since:2022-07-13 until:2022-07-14
# antivegan exvegan yestomeat meatlover antiveganism since:2022-07-14 until:2022-07-15
# antivegan exvegan yestomeat meatlover antiveganism since:2022-07-15 until:2022-07-16
# antivegan exvegan yestomeat meatlover antiveganism since:2022-07-16 until:2022-07-17
# antivegan exvegan yestomeat meatlover antiveganism since:2022-07-17 until:2022-07-18
# antivegan exvegan yestomeat meatlover antiveganism since:2022-07-18 until:2022-07-19
# antivegan exvegan yestomeat meatlover antiveganism since:2022-07-19 until:2022-07-20
# antivegan exvegan yestomeat meatlover antiveganism since:2022-07-20 until:2022-07-21
# antivegan exvegan yestomeat meatlover antiveganism since:2022-07-21 until:2022-07-22
# antivegan exvegan yestomeat meatlover antiveganism since:2022-07-22 until:2022-07-23
# antivegan exvegan yestomeat meatlover antiveganism since:2022-07-23 until:2022-07-24
# antivegan exvegan yestomeat meatlover antiveganism since:2022-07-24 until:2022-07-25
# antivegan exvegan yestomeat meatlover antiveganism since:2022-07-25 until:2022-07-26
# antivegan exvegan yestomeat meatlover antiveganism since:2022-07-26 until:2022-07-27
# antivegan exvegan yestomeat meatlover antiveganism since:2022-07-27 until:2022-07-28
# antivegan exvegan yestomeat meatlover antiveganism since:2022-07-28 until:2022-07-29
# antivegan exvegan yestomeat meatlover antiveganism since:2022-07-29 until:2022-07-30
# antivegan exvegan yestomeat meatlover antiveganism since:2022-07-30 until:2022-07-31
# antivegan exvegan yestomeat meatlover antiveganism since:2022-07-31 until:2022-08-01
# antivegan exvegan yestomeat meatlover antiveganism since:2022-08-01 until:2022-08-02
# antivegan exvegan yestomeat meatlover antiveganism since:2022-08-02 until:2022-08-03
# antivegan exvegan yestomeat meatlover antiveganism since:2022-08-03 until:2022-08-04
# antivegan exvegan yestomeat meatlover antiveganism since:2022-08-04 until:2022-08-05
# antivegan exvegan yestomeat meatlover antiveganism since:2022-08-05 until:2022-08-06
# antivegan exvegan yestomeat meatlover antiveganism since:2022-08-06 until:2022-08-07
# antivegan exvegan yestomeat meatlover antiveganism since:2022-08-07 until:2022-08-08
# antivegan exvegan yestomeat meatlover antiveganism since:2022-08-08 until:2022-08-09
# antivegan exvegan yestomeat meatlover antiveganism since:2022-08-09 until:2022-08-10
# antivegan exvegan yestomeat meatlover antiveganism since:2022-08-10 until:2022-08-11
# antivegan exvegan yestomeat meatlover antiveganism since:2022-08-11 until:2022-08-12
# antivegan exvegan yestomeat meatlover antiveganism since:2022-08-12 until:2022-08-13
# antivegan exvegan yestomeat meatlover antiveganism since:2022-08-13 until:2022-08-14
# antivegan exvegan yestomeat meatlover antiveganism since:2022-08-14 until:2022-08-15
# antivegan exvegan yestomeat meatlover antiveganism since:2022-08-15 until:2022-08-16
# antivegan exvegan yestomeat meatlover antiveganism since:2022-08-16 until:2022-08-17
# antivegan exvegan yestomeat meatlover antiveganism since:2022-08-17 until:2022-08-18
# antivegan exvegan yestomeat meatlover antiveganism since:2022-08-18 until:2022-08-19
# antivegan exvegan yestomeat meatlover antiveganism since:2022-08-19 until:2022-08-20
# antivegan exvegan yestomeat meatlover antiveganism since:2022-08-20 until:2022-08-21
# antivegan exvegan yestomeat meatlover antiveganism since:2022-08-21 until:2022-08-22
# antivegan exvegan yestomeat meatlover antiveganism since:2022-08-22 until:2022-08-23
# antivegan exvegan yestomeat meatlover antiveganism since:2022-08-23 until:2022-08-24
# antivegan exvegan yestomeat meatlover antiveganism since:2022-08-24 until:2022-08-25
# antivegan exvegan yestomeat meatlover antiveganism since:2022-08-25 until:2022-08-26
# antivegan exvegan yestomeat meatlover antiveganism since:2022-08-26 until:2022-08-27
# antivegan exvegan yestomeat meatlover antiveganism since:2022-08-27 until:2022-08-28
# antivegan exvegan yestomeat meatlover antiveganism since:2022-08-28 until:2022-08-29
# antivegan exvegan yestomeat meatlover antiveganism since:2022-08-29 until:2022-08-30
# antivegan exvegan yestomeat meatlover antiveganism since:2022-08-30 until:2022-08-31
# antivegan exvegan yestomeat meatlover antiveganism since:2022-08-31 until:2022-09-01
# antivegan exvegan yestomeat meatlover antiveganism since:2022-09-01 until:2022-09-02
# antivegan exvegan yestomeat meatlover antiveganism since:2022-09-02 until:2022-09-03
# antivegan exvegan yestomeat meatlover antiveganism since:2022-09-03 until:2022-09-04
# antivegan exvegan yestomeat meatlover antiveganism since:2022-09-04 until:2022-09-05
# antivegan exvegan yestomeat meatlover antiveganism since:2022-09-05 until:2022-09-06
# antivegan exvegan yestomeat meatlover antiveganism since:2022-09-06 until:2022-09-07
# antivegan exvegan yestomeat meatlover antiveganism since:2022-09-07 until:2022-09-08
# antivegan exvegan yestomeat meatlover antiveganism since:2022-09-08 until:2022-09-09
# antivegan exvegan yestomeat meatlover antiveganism since:2022-09-09 until:2022-09-10
# antivegan exvegan yestomeat meatlover antiveganism since:2022-09-10 until:2022-09-11
# antivegan exvegan yestomeat meatlover antiveganism since:2022-09-11 until:2022-09-12
# antivegan exvegan yestomeat meatlover antiveganism since:2022-09-12 until:2022-09-13
# antivegan exvegan yestomeat meatlover antiveganism since:2022-09-13 until:2022-09-14
# antivegan exvegan yestomeat meatlover antiveganism since:2022-09-14 until:2022-09-15
# antivegan exvegan yestomeat meatlover antiveganism since:2022-09-15 until:2022-09-16
# antivegan exvegan yestomeat meatlover antiveganism since:2022-09-16 until:2022-09-17
# antivegan exvegan yestomeat meatlover antiveganism since:2022-09-17 until:2022-09-18
# antivegan exvegan yestomeat meatlover antiveganism since:2022-09-18 until:2022-09-19
# antivegan exvegan yestomeat meatlover antiveganism since:2022-09-19 until:2022-09-20
# antivegan exvegan yestomeat meatlover antiveganism since:2022-09-20 until:2022-09-21
# antivegan exvegan yestomeat meatlover antiveganism since:2022-09-21 until:2022-09-22
# antivegan exvegan yestomeat meatlover antiveganism since:2022-09-22 until:2022-09-23
# antivegan exvegan yestomeat meatlover antiveganism since:2022-09-23 until:2022-09-24
# antivegan exvegan yestomeat meatlover antiveganism since:2022-09-24 until:2022-09-25
# antivegan exvegan yestomeat meatlover antiveganism since:2022-09-25 until:2022-09-26
# antivegan exvegan yestomeat meatlover antiveganism since:2022-09-26 until:2022-09-27
# antivegan exvegan yestomeat meatlover antiveganism since:2022-09-27 until:2022-09-28
# antivegan exvegan yestomeat meatlover antiveganism since:2022-09-28 until:2022-09-29
# antivegan exvegan yestomeat meatlover antiveganism since:2022-09-29 until:2022-09-30
# antivegan exvegan yestomeat meatlover antiveganism since:2022-09-30 until:2022-10-01
# antivegan exvegan yestomeat meatlover antiveganism since:2022-10-01 until:2022-10-02
# antivegan exvegan yestomeat meatlover antiveganism since:2022-10-02 until:2022-10-03
# antivegan exvegan yestomeat meatlover antiveganism since:2022-10-03 until:2022-10-04
# antivegan exvegan yestomeat meatlover antiveganism since:2022-10-04 until:2022-10-05
# antivegan exvegan yestomeat meatlover antiveganism since:2022-10-05 until:2022-10-06
# antivegan exvegan yestomeat meatlover antiveganism since:2022-10-06 until:2022-10-07
# antivegan exvegan yestomeat meatlover antiveganism since:2022-10-07 until:2022-10-08
# antivegan exvegan yestomeat meatlover antiveganism since:2022-10-08 until:2022-10-09
# antivegan exvegan yestomeat meatlover antiveganism since:2022-10-09 until:2022-10-10
# antivegan exvegan yestomeat meatlover antiveganism since:2022-10-10 until:2022-10-11
# antivegan exvegan yestomeat meatlover antiveganism since:2022-10-11 until:2022-10-12
# antivegan exvegan yestomeat meatlover antiveganism since:2022-10-12 until:2022-10-13
# antivegan exvegan yestomeat meatlover antiveganism since:2022-10-13 until:2022-10-14
# antivegan exvegan yestomeat meatlover antiveganism since:2022-10-14 until:2022-10-15
# antivegan exvegan yestomeat meatlover antiveganism since:2022-10-15 until:2022-10-16
# antivegan exvegan yestomeat meatlover antiveganism since:2022-10-16 until:2022-10-17
# antivegan exvegan yestomeat meatlover antiveganism since:2022-10-17 until:2022-10-18
# antivegan exvegan yestomeat meatlover antiveganism since:2022-10-18 until:2022-10-19
# antivegan exvegan yestomeat meatlover antiveganism since:2022-10-19 until:2022-10-20
# antivegan exvegan yestomeat meatlover antiveganism since:2022-10-20 until:2022-10-21
# antivegan exvegan yestomeat meatlover antiveganism since:2022-10-21 until:2022-10-22
# antivegan exvegan yestomeat meatlover antiveganism since:2022-10-22 until:2022-10-23
# antivegan exvegan yestomeat meatlover antiveganism since:2022-10-23 until:2022-10-24
# antivegan exvegan yestomeat meatlover antiveganism since:2022-10-24 until:2022-10-25
# antivegan exvegan yestomeat meatlover antiveganism since:2022-10-25 until:2022-10-26
# antivegan exvegan yestomeat meatlover antiveganism since:2022-10-26 until:2022-10-27
# antivegan exvegan yestomeat meatlover antiveganism since:2022-10-27 until:2022-10-28
# antivegan exvegan yestomeat meatlover antiveganism since:2022-10-28 until:2022-10-29
# antivegan exvegan yestomeat meatlover antiveganism since:2022-10-29 until:2022-10-30
# antivegan exvegan yestomeat meatlover antiveganism since:2022-10-30 until:2022-10-31
# antivegan exvegan yestomeat meatlover antiveganism since:2022-10-31 until:2022-11-01
# antivegan exvegan yestomeat meatlover antiveganism since:2022-11-01 until:2022-11-02
# antivegan exvegan yestomeat meatlover antiveganism since:2022-11-02 until:2022-11-03
# antivegan exvegan yestomeat meatlover antiveganism since:2022-11-03 until:2022-11-04
# antivegan exvegan yestomeat meatlover antiveganism since:2022-11-04 until:2022-11-05
# antivegan exvegan yestomeat meatlover antiveganism since:2022-11-05 until:2022-11-06
# antivegan exvegan yestomeat meatlover antiveganism since:2022-11-06 until:2022-11-07
# antivegan exvegan yestomeat meatlover antiveganism since:2022-11-07 until:2022-11-08
# antivegan exvegan yestomeat meatlover antiveganism since:2022-11-08 until:2022-11-09
# antivegan exvegan yestomeat meatlover antiveganism since:2022-11-09 until:2022-11-10
# antivegan exvegan yestomeat meatlover antiveganism since:2022-11-10 until:2022-11-11
# antivegan exvegan yestomeat meatlover antiveganism since:2022-11-11 until:2022-11-12
# antivegan exvegan yestomeat meatlover antiveganism since:2022-11-12 until:2022-11-13
# antivegan exvegan yestomeat meatlover antiveganism since:2022-11-13 until:2022-11-14
# antivegan exvegan yestomeat meatlover antiveganism since:2022-11-14 until:2022-11-15
# antivegan exvegan yestomeat meatlover antiveganism since:2022-11-15 until:2022-11-16
# antivegan exvegan yestomeat meatlover antiveganism since:2022-11-16 until:2022-11-17
# antivegan exvegan yestomeat meatlover antiveganism since:2022-11-17 until:2022-11-18
# antivegan exvegan yestomeat meatlover antiveganism since:2022-11-18 until:2022-11-19
# antivegan exvegan yestomeat meatlover antiveganism since:2022-11-19 until:2022-11-20
# antivegan exvegan yestomeat meatlover antiveganism since:2022-11-20 until:2022-11-21
# antivegan exvegan yestomeat meatlover antiveganism since:2022-11-21 until:2022-11-22
# antivegan exvegan yestomeat meatlover antiveganism since:2022-11-22 until:2022-11-23
# antivegan exvegan yestomeat meatlover antiveganism since:2022-11-23 until:2022-11-24
# antivegan exvegan yestomeat meatlover antiveganism since:2022-11-24 until:2022-11-25
# antivegan exvegan yestomeat meatlover antiveganism since:2022-11-25 until:2022-11-26
# antivegan exvegan yestomeat meatlover antiveganism since:2022-11-26 until:2022-11-27
# antivegan exvegan yestomeat meatlover antiveganism since:2022-11-27 until:2022-11-28
# antivegan exvegan yestomeat meatlover antiveganism since:2022-11-28 until:2022-11-29
# antivegan exvegan yestomeat meatlover antiveganism since:2022-11-29 until:2022-11-30
# antivegan exvegan yestomeat meatlover antiveganism since:2022-11-30 until:2022-12-01
# antivegan exvegan yestomeat meatlover antiveganism since:2022-12-01 until:2022-12-02
# antivegan exvegan yestomeat meatlover antiveganism since:2022-12-02 until:2022-12-03
# antivegan exvegan yestomeat meatlover antiveganism since:2022-12-03 until:2022-12-04
# antivegan exvegan yestomeat meatlover antiveganism since:2022-12-04 until:2022-12-05
# antivegan exvegan yestomeat meatlover antiveganism since:2022-12-05 until:2022-12-06
# antivegan exvegan yestomeat meatlover antiveganism since:2022-12-06 until:2022-12-07
# antivegan exvegan yestomeat meatlover antiveganism since:2022-12-07 until:2022-12-08
# antivegan exvegan yestomeat meatlover antiveganism since:2022-12-08 until:2022-12-09
# antivegan exvegan yestomeat meatlover antiveganism since:2022-12-09 until:2022-12-10
# antivegan exvegan yestomeat meatlover antiveganism since:2022-12-10 until:2022-12-11
# antivegan exvegan yestomeat meatlover antiveganism since:2022-12-11 until:2022-12-12
# antivegan exvegan yestomeat meatlover antiveganism since:2022-12-12 until:2022-12-13
# antivegan exvegan yestomeat meatlover antiveganism since:2022-12-13 until:2022-12-14
# antivegan exvegan yestomeat meatlover antiveganism since:2022-12-14 until:2022-12-15
# antivegan exvegan yestomeat meatlover antiveganism since:2022-12-15 until:2022-12-16
# antivegan exvegan yestomeat meatlover antiveganism since:2022-12-16 until:2022-12-17
# antivegan exvegan yestomeat meatlover antiveganism since:2022-12-17 until:2022-12-18
# antivegan exvegan yestomeat meatlover antiveganism since:2022-12-18 until:2022-12-19
# antivegan exvegan yestomeat meatlover antiveganism since:2022-12-19 until:2022-12-20
# antivegan exvegan yestomeat meatlover antiveganism since:2022-12-20 until:2022-12-21
# antivegan exvegan yestomeat meatlover antiveganism since:2022-12-21 until:2022-12-22
# antivegan exvegan yestomeat meatlover antiveganism since:2022-12-22 until:2022-12-23
# antivegan exvegan yestomeat meatlover antiveganism since:2022-12-23 until:2022-12-24
# antivegan exvegan yestomeat meatlover antiveganism since:2022-12-24 until:2022-12-25
# antivegan exvegan yestomeat meatlover antiveganism since:2022-12-25 until:2022-12-26
# antivegan exvegan yestomeat meatlover antiveganism since:2022-12-26 until:2022-12-27
# antivegan exvegan yestomeat meatlover antiveganism since:2022-12-27 until:2022-12-28
# antivegan exvegan yestomeat meatlover antiveganism since:2022-12-28 until:2022-12-29
# antivegan exvegan yestomeat meatlover antiveganism since:2022-12-29 until:2022-12-30
# antivegan exvegan yestomeat meatlover antiveganism since:2022-12-30 until:2022-12-31
# antivegan exvegan yestomeat meatlover antiveganism since:2022-12-31 until:2023-01-01
# antivegan exvegan yestomeat meatlover antiveganism since:2023-01-01 until:2023-01-02
# antivegan exvegan yestomeat meatlover antiveganism since:2023-01-02 until:2023-01-03
# antivegan exvegan yestomeat meatlover antiveganism since:2023-01-03 until:2023-01-04
# antivegan exvegan yestomeat meatlover antiveganism since:2023-01-04 until:2023-01-05
# antivegan exvegan yestomeat meatlover antiveganism since:2023-01-05 until:2023-01-06
# antivegan exvegan yestomeat meatlover antiveganism since:2023-01-06 until:2023-01-07
# antivegan exvegan yestomeat meatlover antiveganism since:2023-01-07 until:2023-01-08
# antivegan exvegan yestomeat meatlover antiveganism since:2023-01-08 until:2023-01-09
# antivegan exvegan yestomeat meatlover antiveganism since:2023-01-09 until:2023-01-10
# antivegan exvegan yestomeat meatlover antiveganism since:2023-01-10 until:2023-01-11
# antivegan exvegan yestomeat meatlover antiveganism since:2023-01-11 until:2023-01-12
# antivegan exvegan yestomeat meatlover antiveganism since:2023-01-12 until:2023-01-13
# antivegan exvegan yestomeat meatlover antiveganism since:2023-01-13 until:2023-01-14
# antivegan exvegan yestomeat meatlover antiveganism since:2023-01-14 until:2023-01-15
# antivegan exvegan yestomeat meatlover antiveganism since:2023-01-15 until:2023-01-16
# antivegan exvegan yestomeat meatlover antiveganism since:2023-01-16 until:2023-01-17
# antivegan exvegan yestomeat meatlover antiveganism since:2023-01-17 until:2023-01-18
# antivegan exvegan yestomeat meatlover antiveganism since:2023-01-18 until:2023-01-19
# antivegan exvegan yestomeat meatlover antiveganism since:2023-01-19 until:2023-01-20
# antivegan exvegan yestomeat meatlover antiveganism since:2023-01-20 until:2023-01-21
# antivegan exvegan yestomeat meatlover antiveganism since:2023-01-21 until:2023-01-22
# antivegan exvegan yestomeat meatlover antiveganism since:2023-01-22 until:2023-01-23
# antivegan exvegan yestomeat meatlover antiveganism since:2023-01-23 until:2023-01-24
# antivegan exvegan yestomeat meatlover antiveganism since:2023-01-24 until:2023-01-25
# antivegan exvegan yestomeat meatlover antiveganism since:2023-01-25 until:2023-01-26
# antivegan exvegan yestomeat meatlover antiveganism since:2023-01-26 until:2023-01-27
# antivegan exvegan yestomeat meatlover antiveganism since:2023-01-27 until:2023-01-28
# antivegan exvegan yestomeat meatlover antiveganism since:2023-01-28 until:2023-01-29
# antivegan exvegan yestomeat meatlover antiveganism since:2023-01-29 until:2023-01-30
# antivegan exvegan yestomeat meatlover antiveganism since:2023-01-30 until:2023-01-31
# antivegan exvegan yestomeat meatlover antiveganism since:2023-01-31 until:2023-02-01
#
#
# TOTAL TIME TAKEN 19.616666666666667 minutes

# %%
print(twitter_data.shape)
twitter_data.head(3)
# Out:
# (711, 14)
#          date                                              tweet lang  \
# 0  2022-06-01  @TheFun96593011 @S_Catsgotmyback @Son_of_Space...   en
# 1  2022-06-01  @TheFun96593011 @S_Catsgotmyback @Son_of_Space...   en
# 2  2022-06-01  @TheFun96593011 @S_Catsgotmyback @Son_of_Space...   en
#
#   retweetCount likeCount replyCount     username user_followersCount  \
# 0            0         2          0  ukwondering                2203
# 1            0         1          2  ukwondering                2203
# 2            0        10          1  ukwondering                2203
#
#   user_friendsCount verifiedStatus  \
# 0              2013          False
# 1              2013          False
# 2              2013          False
#
#                                            tweet_url hastags chr_count  \
# 0  https://twitter.com/ukwondering/status/1532067...    None       430
# 1  https://twitter.com/ukwondering/status/1532067...    None       340
# 2  https://twitter.com/ukwondering/status/1532066...    None       354
#
#           topic
# 0  non veganism
# 1  non veganism
# 2  non veganism

# %%
twitter_data.to_csv('/Users/sbp/Downloads/vegan1_sanchana.csv', index=False)

# %%
def read_copy(path=""):
    for f in os.listdir(path):
        if f.endswith('local.csv'):
            df = pd.read_csv(f, lineterminator='\n')
            df.hastags = df.hastags.apply(lambda x: literal_eval(x) if str(x) not in ['none', 'nan', 'np.nan', 'null', ''] else None)
            return df
